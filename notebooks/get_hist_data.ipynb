# %% [markdown]
# ### Use paid ODDSapi key to get historical nba odds data

# %%
import clean_odds_data.py
# Out:
#   Cell In[3], line 1
#     from clean-odds-data import clean_odds_data
#               ^
# SyntaxError: invalid syntax
